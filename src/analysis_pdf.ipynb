# %%
import pandas as pd

from tabula import read_pdf

# %%
url = "https://hub.iscc-system.org//FileHandler/download/summaryAuditReportFile/NDM4ODNfRVUtSVNDQy1DZXJ0LVBMMjMwLTAxNDczMDAx"
df=pd.read_html(url)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[12], line 2
#       1 url = "https://hub.iscc-system.org//FileHandler/download/summaryAuditReportFile/NDM4ODNfRVUtSVNDQy1DZXJ0LVBMMjMwLTAxNDczMDAx"
# ----> 2 df=pd.read_html(url)
#
# File c:\Python312\Lib\site-packages\pandas\io\html.py:1246, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1230 if isinstance(io, str) and not any(
#    1231     [
#    1232         is_file_like(io),
#    (...)
#    1236     ]
#    1237 ):
#    1238     warnings.warn(
#    1239         "Passing literal html to 'read_html' is deprecated and "
#    1240         "will be removed in a future version. To read from a "
#    (...)
#    1243         stacklevel=find_stack_level(),
# ...

# %%
import tabula
df = tabula.read_pdf("temp_0.pdf", pages=3)
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Python312\Lib\site-packages\tabula\backend.py:108, in SubprocessTabula.call_tabula_java(self, options, path)
#     107 try:
# --> 108     result = subprocess.run(
#     109         args,
#     110         stdout=subprocess.PIPE,
#     111         stderr=subprocess.PIPE,
#     112         stdin=subprocess.DEVNULL,
#     113         check=True,
#     114     )
#     115     if result.stderr:
#
# File c:\Python312\Lib\subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#
# ...
